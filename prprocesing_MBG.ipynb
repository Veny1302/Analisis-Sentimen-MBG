# %% [markdown]
# <a href="https://colab.research.google.com/github/Veny1302/Analisis-Sentimen-MBG/blob/main/prprocesing_MBG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Define the filename
filename = "mbg.csv"

# Specify the path to your CSV file
# Adjusting the path to where 'mbg.csv' is actually located.
file_path = f"/content/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#        conversation_id_str                      created_at  favorite_count  \
# 0      1906494334230577600  Sun Mar 30 23:50:44 +0000 2025               0
# 1      1906356488815407127  Sun Mar 30 23:42:44 +0000 2025               1
# 2      1906490951490789530  Sun Mar 30 23:41:41 +0000 2025               0
# 3      1906489999476080670  Sun Mar 30 23:33:31 +0000 2025               0
# 4      1906489938826412156  Sun Mar 30 23:33:16 +0000 2025               0
# ...                    ...                             ...             ...
# 19953  1954759953035780383  Mon Aug 11 04:23:07 +0000 2025               0
# 19954  1954759681093878004  Mon Aug 11 04:20:00 +0000 2025               0
# 19955  1954758792262062466  Mon Aug 11 04:16:28 +0000 2025               0
# 19956  1954755433497026818  Mon Aug 11 04:03:07 +0000 2025               0
# 19957  1954755342807785957  Mon Aug 11 04:02:45 +0000 2025               0
#
#                                                full_text               id_str  \
# 0       Kesatuan adat di Papua Barat Daya bersatu men...  1906494334230577600
# 1      @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...  1906492320377348606
# 2      @athearss SORRY YEEEE Maafkan diri ini bila be...  1906492056471736800
# 3       Dari adat untuk masa depan: Masyarakat Adat P...  1906489999476080670
# 4       Makan bergizi gratis dan dukungan adat formul...  1906489938826412156
# ...                                                  ...                  ...
# 19953  @Alfi_RPiliang Betul Presiden Prabowo menyatak...  1954760467689390489
# 19954  Pemerintah Klaim Program Makan Bergizi Gratis ...  1954759681093878004
# 19955  good morning kids! semangat menjalani hari SEN...  1954758792262062466
# 19956  Badan Gizi Nasional (BGN) mencatat bahwa pener...  1954755433497026818
# 19957  Badan Gizi Nasional (BGN) mencatat bahwa pener...  1954755342807785957
#
#                                              image_url  \
# 0      https://pbs.twimg.com/media/GnU6er8b0AAI5RO.jpg
# 1                                                  NaN
# 2                                                  NaN
# 3      https://pbs.twimg.com/media/GnU2i7IaIAAtSRZ.jpg
# 4      https://pbs.twimg.com/media/GnU2fUeawAA_mBN.jpg
# ...                                                ...
# 19953                                              NaN
# 19954                                              NaN
# 19955  https://pbs.twimg.com/media/GyCywcMaUAA_TRm.jpg
# 19956                                              NaN
# 19957                                              NaN
#
#       in_reply_to_screen_name lang  location  quote_count  reply_count  \
# 0                         NaN   in       NaN            0            0
# 1                  sunajisuna   in       NaN            0            1
# 2                    athearss   in       NaN            0            1
# 3                         NaN   in       NaN            0            0
# 4                         NaN   in       NaN            0            0
# ...                       ...  ...       ...          ...          ...
# 19953           Alfi_RPiliang   in       NaN            0            0
# 19954                     NaN   in       NaN            0            0
# 19955                     NaN   in       NaN            0           21
# 19956                     NaN   in       NaN            0            0
# 19957                     NaN   in       NaN            0            0
#
#        retweet_count                                          tweet_url  \
# 0                  0  https://x.com/undefined/status/190649433423057...
# 1                  0  https://x.com/undefined/status/190649232037734...
# 2                  0  https://x.com/undefined/status/190649205647173...
# 3                  0  https://x.com/undefined/status/190648999947608...
# 4                  0  https://x.com/undefined/status/190648993882641...
# ...              ...                                                ...
# 19953              0  https://x.com/undefined/status/195476046768939...
# 19954              0  https://x.com/undefined/status/195475968109387...
# 19955              0  https://x.com/undefined/status/195475879226206...
# 19956              0  https://x.com/undefined/status/195475543349702...
# 19957              0  https://x.com/undefined/status/195475534280778...
#
#                user_id_str  username
# 0       979754853302857729       NaN
# 1      1000877021017260032       NaN
# 2      1203390308869758976       NaN
# 3       763785104196075520       NaN
# 4       934886702803505152       NaN
# ...                    ...       ...
# 19953  1720665183188922368       NaN
# 19954  1769451991124832257       NaN
# 19955  1443898214663352336       NaN
# 19956  1868038567202861058       NaN
# 19957  1905037710555054080       NaN
#
# [19958 rows x 15 columns]

# %%
num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 18849.

# %%
import pandas as pd
df = pd.read_csv("/content/mbg.csv")
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1906494334230577600  Sun Mar 30 23:50:44 +0000 2025               0
# 1  1906356488815407127  Sun Mar 30 23:42:44 +0000 2025               1
# 2  1906490951490789530  Sun Mar 30 23:41:41 +0000 2025               0
# 3  1906489999476080670  Sun Mar 30 23:33:31 +0000 2025               0
# 4  1906489938826412156  Sun Mar 30 23:33:16 +0000 2025               0
#
#                                            full_text               id_str  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...  1906494334230577600
# 1  @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...  1906492320377348606
# 2  @athearss SORRY YEEEE Maafkan diri ini bila be...  1906492056471736800
# 3   Dari adat untuk masa depan: Masyarakat Adat P...  1906489999476080670
# 4   Makan bergizi gratis dan dukungan adat formul...  1906489938826412156
#
#                                          image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/media/GnU6er8b0AAI5RO.jpg                     NaN
# 1                                              NaN              sunajisuna
# 2                                              NaN                athearss
# 3  https://pbs.twimg.com/media/GnU2i7IaIAAtSRZ.jpg                     NaN
# 4  https://pbs.twimg.com/media/GnU2fUeawAA_mBN.jpg                     NaN
#
#   lang  location  quote_count  reply_count  retweet_count  \
# 0   in       NaN            0            0              0
# 1   in       NaN            0            1              0
# 2   in       NaN            0            1              0
# 3   in       NaN            0            0              0
# 4   in       NaN            0            0              0
#
#                                            tweet_url          user_id_str  \
# 0  https://x.com/undefined/status/190649433423057...   979754853302857729
# 1  https://x.com/undefined/status/190649232037734...  1000877021017260032
# 2  https://x.com/undefined/status/190649205647173...  1203390308869758976
# 3  https://x.com/undefined/status/190648999947608...   763785104196075520
# 4  https://x.com/undefined/status/190648993882641...   934886702803505152
#
#    username
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Check for missing values in each column of df
print("Missing values in df:")
display(df.isnull().sum())

# Check for duplicate rows in df
print("\nNumber of duplicate rows in df:")
display(df.duplicated().sum())
# Out:
# Missing values in df:
# conversation_id_str            0
# created_at                     0
# favorite_count                 0
# full_text                      0
# id_str                         0
# image_url                   7345
# in_reply_to_screen_name    15582
# lang                           0
# location                   19958
# quote_count                    0
# reply_count                    0
# retweet_count                  0
# tweet_url                      0
# user_id_str                    0
# username                   19958
# dtype: int64
# Number of duplicate rows in df:
# np.int64(1091)

# %%
import pandas as pd
df = pd.read_csv("/content/mbg.csv")
df = df[['created_at', 'full_text','username']].rename(columns={'created_at': 'date', 'full_text': 'tweet'}).drop_duplicates()
df
# Out:
#                                  date  \
# 0      Sun Mar 30 23:50:44 +0000 2025
# 1      Sun Mar 30 23:42:44 +0000 2025
# 2      Sun Mar 30 23:41:41 +0000 2025
# 3      Sun Mar 30 23:33:31 +0000 2025
# 4      Sun Mar 30 23:33:16 +0000 2025
# ...                               ...
# 19953  Mon Aug 11 04:23:07 +0000 2025
# 19954  Mon Aug 11 04:20:00 +0000 2025
# 19955  Mon Aug 11 04:16:28 +0000 2025
# 19956  Mon Aug 11 04:03:07 +0000 2025
# 19957  Mon Aug 11 04:02:45 +0000 2025
#
#                                                    tweet  username
# 0       Kesatuan adat di Papua Barat Daya bersatu men...       NaN
# 1      @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...       NaN
# 2      @athearss SORRY YEEEE Maafkan diri ini bila be...       NaN
# 3       Dari adat untuk masa depan: Masyarakat Adat P...       NaN
# 4       Makan bergizi gratis dan dukungan adat formul...       NaN
# ...                                                  ...       ...
# 19953  @Alfi_RPiliang Betul Presiden Prabowo menyatak...       NaN
# 19954  Pemerintah Klaim Program Makan Bergizi Gratis ...       NaN
# 19955  good morning kids! semangat menjalani hari SEN...       NaN
# 19956  Badan Gizi Nasional (BGN) mencatat bahwa pener...       NaN
# 19957  Badan Gizi Nasional (BGN) mencatat bahwa pener...       NaN
#
# [18849 rows x 3 columns]

# %%
df = pd.DataFrame(df[['tweet']])
df.head()
# Out:
#                                                tweet
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1  @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...
# 2  @athearss SORRY YEEEE Maafkan diri ini bila be...
# 3   Dari adat untuk masa depan: Masyarakat Adat P...
# 4   Makan bergizi gratis dan dukungan adat formul...

# %% [markdown]
# ### PROSES HAPUS DATA DUPLIKAT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18849 entries, 0 to 19957
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  18849 non-null  object
#  1   tweet                 18849 non-null  object
#  2   username              0 non-null      float64
#  3   cleaning              18849 non-null  object
#  4   casefolding_cleaning  18849 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 883.5+ KB

# %%
df.drop_duplicates(subset ="full_text", keep = 'first', inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18586 entries, 0 to 19957
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  18586 non-null  object
# dtypes: object(1)
# memory usage: 290.4+ KB

# %% [markdown]
# ###WORDCLOUD SEBELUM PREPROCESSING

# %%
import pandas as pd
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

df['tweet']= df['tweet'].fillna('')

text = ''.join(df['tweet'].astype(str).tolist())

stopwords = set(STOPWORDS)
stopwords.update(['https', 'co', 'RT', 'amp', 't', 'x'])

wc = WordCloud(
    stopwords=stopwords,
    background_color="white",
    max_words=500,
    width=800,
    height=400
)

wc.generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter

text = " ".join(df["tweet"])

tokens = text.split()
word_counts = Counter(tokens)

# Ambil 20 kata paling sering muncul
top_words = word_counts.most_common(20)
word, count = zip(*top_words)

colors = plt.cm.tab20(range(len(word)))

plt.figure(figsize=(14, 7))
bars = plt.bar(word, count, color=colors)

plt.xlabel("Kata-Kata Sering Muncul", fontsize=12, fontweight='bold')
plt.ylabel("Jumlah Kata", fontsize=12, fontweight='bold')
plt.title("Frekuensi 20 Kata Terbanyak", fontsize=18, fontweight='bold')
plt.xticks(rotation=45)

# Tambahkan angka di atas bar
for bar, num in zip(bars, count):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        num + 1,
        str(num),
        fontsize=8,
        color='black',
        ha='center'
    )

plt.show()

# %%
# !pip install Sastrawi

import pandas as pd
import numpy as np
import re
import string
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.12/dist-packages (1.0.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Re-load df and process it to ensure 'date' column is present
df = pd.read_csv("/content/mbg.csv")
df = df[['created_at', 'full_text', 'username']].rename(columns={'created_at': 'date', 'full_text': 'tweet'}).drop_duplicates()

tweets = df.copy()

tweets['date'] = pd.to_datetime(
    tweets['date'],
    format='%a %b %d %H:%M:%S +0000 %Y'
)

tweets['YearMonth'] = tweets['date'].dt.to_period('M')

monthly_tweets = tweets.groupby('YearMonth').size()

colors = plt.cm.viridis(np.linspace(0, 1, len(monthly_tweets)))

# Plot grafik
plt.figure(figsize=(12, 6))
monthly_tweets.plot(kind='bar', color=colors)

plt.xlabel("Bulan dan Tahun", fontsize=12)
plt.ylabel("Jumlah Tweet", fontsize=12)
plt.title("Jumlah Tweet per Bulan", fontsize=16, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# #PROSES PREPROCESSING DATA

# %% [markdown]
# ### Cleaning

# %%
df_cleaned_text = df[['tweet', 'cleaning']]
display(df_cleaned_text.head())
# Out:
#                                                tweet  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1  @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...
# 2  @athearss SORRY YEEEE Maafkan diri ini bila be...
# 3   Dari adat untuk masa depan: Masyarakat Adat P...
# 4   Makan bergizi gratis dan dukungan adat formul...
#
#                                             cleaning
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1    SORRY YEEEE Maafkan diri ini bila belum setr...
# 2   SORRY YEEEE Maafkan diri ini bila belum setra...
# 3   Dari adat untuk masa depan Masyarakat Adat Pa...
# 4   Makan bergizi gratis dan dukungan adat formul...

# %% [markdown]
# ###Casefolding (Lowercasing)

# %%
df['casefolding_cleaning'] = df['cleaning'].str.lower()
display(df[['tweet', 'cleaning', 'casefolding_cleaning']].head())
# Out:
#                                                tweet  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1  @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...
# 2  @athearss SORRY YEEEE Maafkan diri ini bila be...
# 3   Dari adat untuk masa depan: Masyarakat Adat P...
# 4   Makan bergizi gratis dan dukungan adat formul...
#
#                                             cleaning  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1    SORRY YEEEE Maafkan diri ini bila belum setr...
# 2   SORRY YEEEE Maafkan diri ini bila belum setra...
# 3   Dari adat untuk masa depan Masyarakat Adat Pa...
# 4   Makan bergizi gratis dan dukungan adat formul...
#
#                                 casefolding_cleaning
# 0   kesatuan adat di papua barat daya bersatu men...
# 1    sorry yeeee maafkan diri ini bila belum setr...
# 2   sorry yeeee maafkan diri ini bila belum setra...
# 3   dari adat untuk masa depan masyarakat adat pa...
# 4   makan bergizi gratis dan dukungan adat formul...

# %% [markdown]
# ### Normalisasi Kata

# %%
import pandas as pd

df = pd.read_excel('/content/kamuskatabaku.xlsx')
df.head()
# Out:
#   tidak baku      baku
# 0        gak     tidak
# 1         yg      yang
# 2         sm      sama
# 3        mkn     makan
# 4       skrg  sekarang

# %%
import pandas as pd
import re

df = pd.read_csv("/content/mbg.csv")

df = df[['created_at', 'full_text', 'username']].rename(columns={'created_at': 'date', 'full_text': 'tweet'}).drop_duplicates()
df['cleaning'] = df['tweet'].apply(lambda x: re.sub(r'http\S+|www\S+|@\w+|#\w+|\d+|[.,!?:;"\'`\]\[()]', '', x))
df['casefolding_cleaning'] = df['cleaning'].str.lower()

# --- Step 2: Load the kamuskatabaku.xlsx and create kamus_normalisasi dictionary ---
kamus_df = pd.read_excel('/content/kamuskatabaku.xlsx')
kamus_normalisasi = dict(zip(kamus_df['tidak baku'], kamus_df['baku']))

# --- Step 3: Define the replace_taboo_words function ---
def replace_taboo_words(text, kamus):
    if not isinstance(text, str): # Handle non-string inputs gracefully
        return text, [], [], []

    tokens = text.split()
    normalized_tokens = []
    kata_baku_list = []
    kata_tidak_baku_list = []
    kata_tidak_baku_hash_list = []

    for token in tokens:
        # Check if the word is in the dictionary (case-insensitive for lookup, but replace with exact baku form)
        normalized_word = kamus.get(token.lower(), token) # Use .get to return original token if not found
        normalized_tokens.append(normalized_word)

        if token.lower() in kamus: # If it was a non-baku word that got normalized
            kata_tidak_baku_list.append(token)
            kata_baku_list.append(normalized_word)
            kata_tidak_baku_hash_list.append(f'{token}#{normalized_word}')

    return ' '.join(normalized_tokens), kata_baku_list, kata_tidak_baku_list, kata_tidak_baku_hash_list

# --- Step 4: Apply the function to the 'casefolding_cleaning' column ---
# The original code used 'case_folding', here we map it to 'casefolding_cleaning'

df['hasil_normalisasi'], df['Kata_Baku'], df['Kata_Tidak_Baku'], df['Kata_Tidak_Baku_Hash'] = zip(
    *df['casefolding_cleaning'].apply(lambda x: replace_taboo_words(x, kamus_normalisasi))
)

# Display the results
display(df[['tweet', 'cleaning', 'casefolding_cleaning', 'hasil_normalisasi']].head())
# Out:
#                                                tweet  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1  @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...
# 2  @athearss SORRY YEEEE Maafkan diri ini bila be...
# 3   Dari adat untuk masa depan: Masyarakat Adat P...
# 4   Makan bergizi gratis dan dukungan adat formul...
#
#                                             cleaning  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1    SORRY YEEEE Maafkan diri ini bila belum setr...
# 2   SORRY YEEEE Maafkan diri ini bila belum setra...
# 3   Dari adat untuk masa depan Masyarakat Adat Pa...
# 4   Makan bergizi gratis dan dukungan adat formul...
#
#                                 casefolding_cleaning  \
# 0   kesatuan adat di papua barat daya bersatu men...
# 1    sorry yeeee maafkan diri ini bila belum setr...
# 2   sorry yeeee maafkan diri ini bila belum setra...
# 3   dari adat untuk masa depan masyarakat adat pa...
# 4   makan bergizi gratis dan dukungan adat formul...
#
#                                    hasil_normalisasi
# 0  kesatuan adat di papua barat daya bersatu mend...
# 1  sorry yeeee maafkan diri ini bila belum setran...
# 2  sorry yeeee maafkan diri ini bila belum setran...
# 3  dari adat untuk masa depan masyarakat adat pap...
# 4  makan bergizi gratis dan dukungan adat formula...

# %% [markdown]
# ### Tokenization

# %%
def tokenize(text):
  tokens = text.split()
  return tokens

df['tokenize'] = df['hasil_normalisasi'].apply(tokenize)
display(df[['tweet', 'cleaning', 'casefolding_cleaning', 'hasil_normalisasi', 'tokenize']].head())
# Out:
#                                                tweet  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1  @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...
# 2  @athearss SORRY YEEEE Maafkan diri ini bila be...
# 3   Dari adat untuk masa depan: Masyarakat Adat P...
# 4   Makan bergizi gratis dan dukungan adat formul...
#
#                                             cleaning  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1    SORRY YEEEE Maafkan diri ini bila belum setr...
# 2   SORRY YEEEE Maafkan diri ini bila belum setra...
# 3   Dari adat untuk masa depan Masyarakat Adat Pa...
# 4   Makan bergizi gratis dan dukungan adat formul...
#
#                                 casefolding_cleaning  \
# 0   kesatuan adat di papua barat daya bersatu men...
# 1    sorry yeeee maafkan diri ini bila belum setr...
# 2   sorry yeeee maafkan diri ini bila belum setra...
# 3   dari adat untuk masa depan masyarakat adat pa...
# 4   makan bergizi gratis dan dukungan adat formul...
#
#                                    hasil_normalisasi  \
# 0  kesatuan adat di papua barat daya bersatu mend...
# 1  sorry yeeee maafkan diri ini bila belum setran...
# 2  sorry yeeee maafkan diri ini bila belum setran...
# 3  dari adat untuk masa depan masyarakat adat pap...
# 4  makan bergizi gratis dan dukungan adat formula...
#
#                                             tokenize
# 0  [kesatuan, adat, di, papua, barat, daya, bersa...
# 1  [sorry, yeeee, maafkan, diri, ini, bila, belum...
# 2  [sorry, yeeee, maafkan, diri, ini, bila, belum...
# 3  [dari, adat, untuk, masa, depan, masyarakat, a...
# 4  [makan, bergizi, gratis, dan, dukungan, adat, ...

# %% [markdown]
# ### Stopword Removal

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.12/dist-packages (1.0.1)

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import requests

# Load custom stopword list from a URL
# This URL provides a more comprehensive list than the default Sastrawi list.
url_stopwords = "https://raw.githubusercontent.com/stopwords/id/master/id.txt"
response = requests.get(url_stopwords)
custom_stopwords = response.text.splitlines()

# Extend Sastrawi's default stopword list with custom stopwords
factory = StopWordRemoverFactory()
stopwords_sastrawi = factory.get_stop_words()
all_stopwords = set(stopwords_sastrawi + custom_stopwords)

def remove_stopwords(text_tokens):
    if isinstance(text_tokens, list):
        return [word for word in text_tokens if word not in all_stopwords]
    return []

# Let's re-tokenize 'hasil_normalisasi' to be safe, as normalized_text might not be a list of tokens
df['tokenized_normalized_text'] = df['hasil_normalisasi'].apply(lambda x: x.split() if isinstance(x, str) else [])
df['stopword_removed'] = df['tokenized_normalized_text'].apply(remove_stopwords)

display(df[['tweet', 'cleaning', 'casefolding_cleaning', 'hasil_normalisasi', 'tokenize', 'stopword_removed']].head())
# Out:
#                                                tweet  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1  @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...
# 2  @athearss SORRY YEEEE Maafkan diri ini bila be...
# 3   Dari adat untuk masa depan: Masyarakat Adat P...
# 4   Makan bergizi gratis dan dukungan adat formul...
#
#                                             cleaning  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1    SORRY YEEEE Maafkan diri ini bila belum setr...
# 2   SORRY YEEEE Maafkan diri ini bila belum setra...
# 3   Dari adat untuk masa depan Masyarakat Adat Pa...
# 4   Makan bergizi gratis dan dukungan adat formul...
#
#                                 casefolding_cleaning  \
# 0   kesatuan adat di papua barat daya bersatu men...
# 1    sorry yeeee maafkan diri ini bila belum setr...
# 2   sorry yeeee maafkan diri ini bila belum setra...
# 3   dari adat untuk masa depan masyarakat adat pa...
# 4   makan bergizi gratis dan dukungan adat formul...
#
#                                    hasil_normalisasi  \
# 0  kesatuan adat di papua barat daya bersatu mend...
# 1  sorry yeeee maafkan diri ini bila belum setran...
# 2  sorry yeeee maafkan diri ini bila belum setran...
# 3  dari adat untuk masa depan masyarakat adat pap...
# 4  makan bergizi gratis dan dukungan adat formula...
#
#                                             tokenize  \
# 0  [kesatuan, adat, di, papua, barat, daya, bersa...
# 1  [sorry, yeeee, maafkan, diri, ini, bila, belum...
# 2  [sorry, yeeee, maafkan, diri, ini, bila, belum...
# 3  [dari, adat, untuk, masa, depan, masyarakat, a...
# 4  [makan, bergizi, gratis, dan, dukungan, adat, ...
#
#                                     stopword_removed
# 0  [kesatuan, adat, papua, barat, daya, bersatu, ...
# 1  [sorry, yeeee, maafkan, diri, bila, setranspar...
# 2  [sorry, yeeee, maafkan, diri, bila, setranspar...
# 3  [adat, masa, depan, masyarakat, adat, papua, b...
# 4  [makan, bergizi, gratis, dukungan, adat, formu...

# %% [markdown]
# ### Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stem_text(tokens):
    if isinstance(tokens, list):
        return [stemmer.stem(word) for word in tokens]
    return []

df['stemming_data'] = df['stopword_removed'].apply(stem_text)

display(df[['tweet', 'cleaning', 'casefolding_cleaning', 'hasil_normalisasi', 'tokenized_normalized_text', 'stopword_removed', 'stemming_data']].head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1018452465.py in <cell line: 0>()
#      10     return []
#      11
# ---> 12 df['stemming_data'] = df['stopword_removed'].apply(stem_text)
#      13
#      14 display(df[['tweet', 'cleaning', 'casefolding_cleaning', 'hasil_normalisasi', 'tokenized_normalized_text', 'stopword_removed', 'stemming_data']].head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipython-input-1018452465.py in stem_text(tokens)
#       7 def stem_text(tokens):
#       8     if isinstance(tokens, list):
# ----> 9         return [stemmer.stem(word) for word in tokens]
#      10     return []
#      11
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/CachedStemmer.py in stem(self, text)
#      18                 stems.append(self.cache.get(word))
#      19             else:
# ---> 20                 stem = self.delegatedStemmer.stem(word)
#      21                 self.cache.set(word, stem)
#      22                 stems.append(stem)
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Stemmer.py in stem(self, text)
#      25
#      26         for word in words:
# ---> 27             stems.append(self.stem_word(word))
#      28
#      29         return ' '.join(stems)
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Stemmer.py in stem_word(self, word)
#      34             return self.stem_plural_word(word)
#      35         else:
# ---> 36             return self.stem_singular_word(word)
#      37
#      38     def is_plural(self, word):
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Stemmer.py in stem_singular_word(self, word)
#      82         """Stem a singular word to its common stem form."""
#      83         context = Context(word, self.dictionary, self.visitor_provider)
# ---> 84         context.execute()
#      85
#      86         return context.result
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Context/Context.py in execute(self)
#      35
#      36         #step 1 - 5
# ---> 37         self.start_stemming_process()
#      38
#      39         #step 6
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Context/Context.py in start_stemming_process(self)
#      83
#      84         #ECS loop pengembalian akhiran
# ---> 85         self.loop_pengembalian_akhiran()
#      86
#      87     def remove_prefixes(self):
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Context/Context.py in loop_pengembalian_akhiran(self)
#     139
#     140             #step 4,5
# --> 141             self.remove_prefixes()
#     142             if self.dictionary.contains(self.current_word):
#     143                 return
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Context/Context.py in remove_prefixes(self)
#      87     def remove_prefixes(self):
#      88         for i in range(3):
# ---> 89             self.accept_prefix_visitors(self.prefix_pisitors)
#      90             if self.dictionary.contains(self.current_word):
#      91                 return
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Context/Context.py in accept_prefix_visitors(self, visitors)
#     108         removalCount = len(self.removals)
#     109         for visitor in visitors:
# --> 110             self.accept(visitor)
#     111             if self.dictionary.contains(self.current_word):
#     112                 return self.current_word
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Context/Context.py in accept(self, visitor)
#      95
#      96     def accept(self, visitor):
# ---> 97         visitor.visit(self)
#      98
#      99     def accept_visitors(self, visitors):
#
# /usr/local/lib/python3.12/dist-packages/Sastrawi/Stemmer/Context/Visitor/AbstractDisambiguatePrefixRule.py in visit(self, context)
#      13         for disambiguator in self.disambiguators:
#      14             result = disambiguator.disambiguate(context.current_word)
# ---> 15             if context.dictionary.contains(result):
#      16                 break
#      17
#
# KeyboardInterrupt:

# %% [markdown]
# ###Proses Hapus Data Bernilai Kosong (NAN)

# %%
df.info()

# %%
data = df.dropna()
data.info()

# %% [markdown]
# ###WORDCLOUD SETELAH PREPROCESSING

# %%
import pandas as pd
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# Use 'df' instead of 'data' as 'data' is empty
text = ' '.join(df['stemming_data'].astype(str).tolist())

stopwords = set(STOPWORDS)
stopwords.update(['https', 'co', 'RT', 'amp', 't', 'x', 'fyp', 'lu', 'yg'])

wc = WordCloud(
    stopwords=stopwords,
    background_color="white",
    max_words=500,
    width=800,
    height=400
)

wc.generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
from collections import Counter

text = " ".join(df["stemming_data"])

# Tokenize the text and count word frequencies
tokens = text.split()
word_counts = Counter(tokens)

stopwords = set (STOPWORDS)
stopwords.update(["https", "co", "RT", "amp", "t", "x", "fyp", "lu", "yg"])
# Ambil 20 kata paling sering muncul
top_words = word_counts.most_common(20)
word, count = zip(*top_words)

colors = plt.cm.tab20(range(len(word)))

plt.figure(figsize=(14, 7))
bars = plt.bar(word, count, color=colors)

plt.xlabel("Kata-Kata Sering Muncul", fontsize=12, fontweight='bold')
plt.ylabel("Jumlah Kata", fontsize=12, fontweight='bold')
plt.title("Frekuensi 20 Kata Terbanyak", fontsize=18, fontweight='bold')
plt.xticks(rotation=45)

# Tambahkan angka di atas bar
for bar, num in zip(bars, count):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        num + 1,
        str(num),
        fontsize=8,
        color='black',
        ha='center'
    )

plt.show()

# %%
df.to_excel('data_preprocessing.xlsx', index=False)

# %% [markdown]
# ###PELABELAN DATA MENGGUNAKAN LEXICON BASED

# %%
import pandas as pd

import requests

# Unduh kamus leksikon positif dan negatif dari GitHub

positive_url = "https://raw.githubusercontent.com/fajri91/InSet/master/positive.tsv"
negative_url = "https://raw.githubusercontent.com/fajri91/InSet/master/negative.tsv" # Corrected URL

# Import lexicon data
positive_lexicon = set(pd.read_csv(positive_url, sep="\t", header=None)[0])
negative_lexicon = set(pd.read_csv(negative_url, sep="\t", header=None)[0])


# Fungsi untuk menentukan sentimen dan menghitung skor
def determine_sentiment(text):
    if isinstance(text, str):

        # Hitung jumlah kata positif & negatif
        positive_count = sum(1 for word in text.split() if word in positive_lexicon)
        negative_count = sum(1 for word in text.split() if word in negative_lexicon)

        # Hitung total skor
        sentiment_score = positive_count - negative_count

        # Tentukan label sentimen
        if sentiment_score > 0:
            sentiment = "Positif"
        elif sentiment_score < 0:
            sentiment = "Negatif"
        else:
            sentiment = "Netral"

        return sentiment_score, sentiment

    return 0, "Netral"


df['sentiment_score'], df['sentiment_label'] = zip(*df['stemming_data'].apply(lambda x: determine_sentiment(x)))

# Menampilkan hasil 5 baris pertama
display(df[[ 'stemming_data', 'sentiment_score', 'sentiment_label']].head(6))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sentiment_count = df['sentiment_label'].value_counts() # Corrected: use df and sentiment_label
sns.set_style('whitegrid')

fig, ax = plt.subplots(figsize=(6, 4)) # Corrected: syntax for subplots and figsize

ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel') # Corrected: syntax for x, y, and palette

plt.title("Jumlah Analisis Sentimen", fontsize=14, pad=20) # Corrected: title string
plt.xlabel('Class Sentiment', fontsize=12)
plt.ylabel('Jumlah Tweet', fontsize=12)

total = len(df['sentiment_label']) # Corrected: use df and sentiment_label

for i, count in enumerate(sentiment_count.values):
    percentage = f'{(100 * count / total):.2f}%' # Corrected: f-string for percentage
    ax.text(i, count + 0.10, f'{count}\n({percentage})', ha='center', va='bottom') # Corrected: f-string for text annotation

plt.show()

# %% [markdown]
# #WORDCLOUD LABEL POSITIF NEGATIF NETRAL

# %%
import pandas as pd

data = pd.read_excel('/content/data_labeling.xlsx')
data.head(6)
# Out:
#                              date  \
# 0  Sun Mar 30 23:50:44 +0000 2025
# 1  Sun Mar 30 23:42:44 +0000 2025
# 2  Sun Mar 30 23:41:41 +0000 2025
# 3  Sun Mar 30 23:33:31 +0000 2025
# 4  Sun Mar 30 23:33:16 +0000 2025
# 5  Sun Mar 30 23:23:20 +0000 2025
#
#                                                tweet  username  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...       NaN
# 1  @ajinomongapain @Falkenhaynz SORRY YEEEE Maafk...       NaN
# 2  @athearss SORRY YEEEE Maafkan diri ini bila be...       NaN
# 3   Dari adat untuk masa depan: Masyarakat Adat P...       NaN
# 4   Makan bergizi gratis dan dukungan adat formul...       NaN
# 5   Dukungan penuh dari Lembaga Masyarakat Adat P...       NaN
#
#                                             cleaning  \
# 0   Kesatuan adat di Papua Barat Daya bersatu men...
# 1    SORRY YEEEE Maafkan diri ini bila belum setr...
# 2   SORRY YEEEE Maafkan diri ini bila belum setra...
# 3   Dari adat untuk masa depan Masyarakat Adat Pa...
# 4   Makan bergizi gratis dan dukungan adat formul...
# 5   Dukungan penuh dari Lembaga Masyarakat Adat P...
#
#                                 casefolding_cleaning  \
# 0   kesatuan adat di papua barat daya bersatu men...
# 1    sorry yeeee maafkan diri ini bila belum setr...
# 2   sorry yeeee maafkan diri ini bila belum setra...
# 3   dari adat untuk masa depan masyarakat adat pa...
# 4   makan bergizi gratis dan dukungan adat formul...
# 5   dukungan penuh dari lembaga masyarakat adat p...
#
#                                    hasil_normalisasi      Kata_Baku  \
# 0  kesatuan adat di papua barat daya bersatu mend...             []
# 1  sorry yeeee maafkan diri ini bila belum setran...             []
# 2  sorry yeeee maafkan diri ini bila belum setran...             []
# 3  dari adat untuk masa depan masyarakat adat pap...  ['mendukung']
# 4  makan bergizi gratis dan dukungan adat formula...             []
# 5  dukungan penuh dari lembaga masyarakat adat pa...             []
#
#   Kata_Tidak_Baku  Kata_Tidak_Baku_Hash  \
# 0              []                    []
# 1              []                    []
# 2              []                    []
# 3      ['dukung']  ['dukung#mendukung']
# 4              []                    []
# 5              []                    []
#
#                                             tokenize  \
# 0  ['kesatuan', 'adat', 'di', 'papua', 'barat', '...
# 1  ['sorry', 'yeeee', 'maafkan', 'diri', 'ini', '...
# 2  ['sorry', 'yeeee', 'maafkan', 'diri', 'ini', '...
# 3  ['dari', 'adat', 'untuk', 'masa', 'depan', 'ma...
# 4  ['makan', 'bergizi', 'gratis', 'dan', 'dukunga...
# 5  ['dukungan', 'penuh', 'dari', 'lembaga', 'masy...
#
#                            tokenized_normalized_text  \
# 0  ['kesatuan', 'adat', 'di', 'papua', 'barat', '...
# 1  ['sorry', 'yeeee', 'maafkan', 'diri', 'ini', '...
# 2  ['sorry', 'yeeee', 'maafkan', 'diri', 'ini', '...
# 3  ['dari', 'adat', 'untuk', 'masa', 'depan', 'ma...
# 4  ['makan', 'bergizi', 'gratis', 'dan', 'dukunga...
# 5  ['dukungan', 'penuh', 'dari', 'lembaga', 'masy...
#
#                                     stopword_removed  \
# 0  ['kesatuan', 'adat', 'papua', 'barat', 'daya',...
# 1  ['sorry', 'yeeee', 'maafkan', 'diri', 'bila', ...
# 2  ['sorry', 'yeeee', 'maafkan', 'diri', 'bila', ...
# 3  ['adat', 'masa', 'depan', 'masyarakat', 'adat'...
# 4  ['makan', 'bergizi', 'gratis', 'dukungan', 'ad...
# 5  ['dukungan', 'penuh', 'lembaga', 'masyarakat',...
#
#                                         stemmed_text  \
# 0  ['satu', 'adat', 'papua', 'barat', 'daya', 'sa...
# 1  ['sorry', 'yeeee', 'maaf', 'diri', 'bila', 'tr...
# 2  ['sorry', 'yeeee', 'maaf', 'diri', 'bila', 'tr...
# 3  ['adat', 'masa', 'depan', 'masyarakat', 'adat'...
# 4  ['makan', 'gizi', 'gratis', 'dukung', 'adat', ...
# 5  ['dukung', 'penuh', 'lembaga', 'masyarakat', '...
#
#                                        stemming_data  sentiment_score  \
# 0  satu adat papua barat daya satu dukung makan g...                2
# 1  sorry yeeee maaf diri bila transparan buat ruu...               -3
# 2  sorry yeeee maaf diri bila transparan buat ruu...               -3
# 3  adat masa depan masyarakat adat papua barat da...                2
# 4  makan gizi gratis dukung adat formula sukses p...                3
# 5  dukung penuh lembaga masyarakat adat papua bar...                2
#
#   sentiment_label
# 0         Positif
# 1         Negatif
# 2         Negatif
# 3         Positif
# 4         Positif
# 5         Positif

# %%
display(data[['stemming_data', 'sentiment_score', 'sentiment_label']].head())
# Out:
#                                        stemming_data  sentiment_score  \
# 0  satu adat papua barat daya satu dukung makan g...                2
# 1  sorry yeeee maaf diri bila transparan buat ruu...               -3
# 2  sorry yeeee maaf diri bila transparan buat ruu...               -3
# 3  adat masa depan masyarakat adat papua barat da...                2
# 4  makan gizi gratis dukung adat formula sukses p...                3
#
#   sentiment_label
# 0         Positif
# 1         Negatif
# 2         Negatif
# 3         Positif
# 4         Positif

# %% [markdown]
# ###Wordclod Positif

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Load the processed DataFrame from the saved Excel file
data = pd.read_excel('/content/data_labeling.xlsx')

# Define the generate_wordCloud function
def generate_wordCloud(text_data, title):
    stopwords = set(STOPWORDS)
    stopwords.update(['https', 'co', 'RT', 'amp', 't', 'x', 'fyp', 'lu', 'yg'])

    wordcloud = WordCloud(
        stopwords=stopwords,
        background_color="white",
        max_words=500,
        width=800,
        height=400
    ).generate(text_data)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(title)
    plt.show()

# Filter df for positive sentiment data
sentimen_positive_df = data[data['sentiment_label'] == 'Positif']

# Prepare the text for the word cloud
sentimen_positive = ' '.join(sentimen_positive_df['stemming_data'].astype(str).tolist())

# Call the function for positive sentiment
generate_wordCloud(sentimen_positive, "Word Cloud Sentimen Positif")
